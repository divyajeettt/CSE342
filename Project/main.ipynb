# %% [markdown]
# # **CSE342: Statistical Machine Learning (Course Project)**
#
# This notebook contains a potential solution course project for Statistical Machine Learning (Winter 2023). The project was hosted as a private competitive Kaggle contest.
#
# The goal of the project is to build a classifier to label the images in the test set into one of 19 different classes of fruits. The dataset consists of $64 \times 64$ pixel images of fruits, however, only a total of $1216$ records are available for training.
#
# The challenge is to build a robust classifier using the limited training data, that generalizes well and is not overfitted to the training data.

# %% [markdown]
# ## **Importing the required libraries**
#
# The `sklearn` library is heavily used to access efficient implementations of popular machine learning algorithms which were covered in the course. `numpy` and `matplotlib.pyplot` are some other libraries that are used for data manipulation and visualization.
# A self-implemented `data.py` file is used to load the data from the given file.

# %%
import data
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import LocalOutlierFactor as LOF
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Loading the data**
#
# The data is loaded using the `Dataset` class implemented in the `data.py` file. This class is used to preprocess the labelling of the data. It can also be used to one-hot encode features, if required, though it is not used in this project.

# %%
train_data = data.Dataset("train.csv")
train_data.x.shape
# Out:
# (1216, 4096)

# %% [markdown]
# ## **Data Analysis and Sanity Check**
#
# The data is analysed for patterns and similarities, while the sanity check ensures that the data is loaded correctly.

# %% [markdown]
# ### **Data Analysis**
#
# The main analysis comprises of finding the distribution of the labels in the dataset. The distribution is shown below. It is clear that the dataset is highly imbalanced and the distribution is non-gaussian.

# %%
labels = train_data.get_cat_to_label()
counts = [train_data.y[train_data.y == i].shape[0] for i in labels]

print(dict(zip(labels.values(), counts)))
print("Average number of samples per class:", np.mean(counts))

plt.figure(figsize=(14, 4.5))
plt.bar([value if i%2 else f"\n{value}" for i, value in labels.items()], counts)
plt.title("Number of samples per class")
plt.show()
# Out:
# {'Orange_Ripe': 54, 'Banana_Ripe': 86, 'Mango_Raw': 72, 'Leeche_Raw': 37, 'Mango_Ripe': 46, 'Papaya_Ripe': 77, 'Guava_Ripe': 56, 'Apple_Ripe': 81, 'Pomengranate_Ripe': 57, 'Guava_Raw': 45, 'Strawberry_Raw': 65, 'Apple_Raw': 78, 'Leeche_Ripe': 55, 'Papaya_Raw': 51, 'Strawberry_Ripe': 75, 'Pomengranate_Raw': 58, 'Coconut_Ripe': 58, 'Banana_Raw': 63, 'Coconut_Raw': 54, 'Orange_Raw': 48}
# Average number of samples per class: 60.8

# %% [markdown]
# ### **Sanity Check**
#
# $10$ randomly selected images from the dataset are displayed below. The images are displayed in a $64 \times 64$ pixel format. The labels are also displayed above each image. Each image essentially looked like noise. After multiple trials, it was concluded that the features of the dataset must have been shuffled to prevent cheating (by plotting and manually labelling the test set).
#
# Hence, the sanity check failed.

# %%
# Select 10 random indices
indices = np.random.choice(len(train_data.x), size=10, replace=False)
labels = train_data.get_cat_to_label()

# Sanity Check: Plot the images and their labels
plot = plt.figure(figsize=(10, 4))
for i, index in enumerate(indices):
    plt.subplot(2, 5, i+1)
    plt.imshow(train_data.x[index].reshape(64, 64), cmap="gray")
    plt.title(labels[train_data.y[index]])
    plt.axis("off")
plt.show()

# %% [markdown]
# ## **Data Preprocessing**
#
# The data is preprocessed to remove potential outliers that could affect the performance of the classifier. The data is also standardized to have zero mean and unit variance.

# %% [markdown]
# ### **Removing Outliers (Local Outlier Factor Algorithm)**
#
# The `LOF` algorithm is used to remove outliers from the dataset based on their abnormally low densities. However, since the dataset is limited, the algorithm is tuned to detect only the most extreme outliers. The algorithm is run on the training data only, and the outliers are removed from the training data.

# %%
lof = LOF(n_neighbors=10, contamination=0.01)
outlier_labels = lof.fit_predict(train_data.x)

print("Number of Outliers:", np.sum(outlier_labels == -1))

train_data.x = train_data.x[outlier_labels == 1]
train_data.y = train_data.y[outlier_labels == 1]
# Out:
# Number of Outliers: 13

# %% [markdown]
# ## **Standardization**
#
# The data is standardized to have zero mean and unit variance. This is done to prevent any features from dominating the classifier. Since this project deals with an image classifier, it is all the more important to standardize the data.

# %%
scaler = StandardScaler()
train_data.x = scaler.fit_transform(train_data.x)

# %% [markdown]
# ### **Checking Features**
#
# Two features are randomly selected and checked to ensure that they are standardized. The features are plotted as histograms to check their distributions. The features are also plotted as boxplots to check for outliers. The plots are shown below.

# %%
f1, f2 = np.random.randint(0, 4096, size=2)

plt.figure(figsize=(12, 5))
plt.hist(train_data.x[:, f1], bins=75, alpha=0.75, label=f"Feature {f1}")
plt.hist(train_data.x[:, f2], bins=75, alpha=0.75, label=f"Feature {f2}")
plt.axvline(x=0, color="black", linestyle="--")

plt.title("Feature Distribution")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Train-Test Split**
#
# The data is split into training and test sets in a $80:20$ ratio. The training set is used to train the classifier, and the test set is used to validate the performance of the classifier.
#
# *(**Note:** More preprocessing steps (as mentioned in the report) are utilized using a pipeline after finding the optimal hyperparameter values)*

# %%
x_train, x_test, y_train, y_test = train_test_split(train_data.x, train_data.y, test_size=0.20)

# %% [markdown]
# ## **Building the Classifier using Pipeline**
#
# The classifier is built using a pipeline. The pipeline consists of the following steps:
# - (Preprocessing) Principal Component Analysis (PCA)
# - (Preprocessing) Linear Discriminant Analysis (LDA)
# - (Classifier) Multinomial Logistic Regression
#
# The proposed pipeline is selected after multiple validations and failures of different models like $k$-NN, Random Forest, $X$-Gradient Boosting, (Gaussian) Naive Bayes, and Shallow Neural Networks.
#
# `GridSearchCV` is used to exhaustively search for the optimal hyperparameter values for each algorithm of the pipeline. The hyperparameters are tuned by using a $5$-fold cross-validation on the training set.

# %%
pipe = Pipeline([
    ("pca", PCA()),
    ("lda", LDA()),
    ("lr", LogisticRegression(max_iter=10000))
])

param_grid = {
    "pca__n_components": [256, 512, 784],
    "lda__n_components": [10, 15, None],
    "lr__C": [0.1, 1, 10],
    "lr__solver": ["lbfgs", "sag"],   
}

grid = GridSearchCV(pipe, param_grid, cv=5, verbose=3, n_jobs=-1)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5] END lda__n_components=10, lr__C=0.1, lr__solver=lbfgs, pca__n_components=256;, score=0.717 total time=   1.7s
# [CV 3/5] END lda__n_components=10, lr__C=0.1, lr__solver=lbfgs, pca__n_components=256;, score=0.717 total time=   2.6s
# [CV 2/5] END lda__n_components=10, lr__C=0.1, lr__solver=lbfgs, pca__n_components=256;, score=0.648 total time=   2.6s
# [CV 4/5] END lda__n_components=10, lr__C=0.1, lr__solver=lbfgs, pca__n_components=256;, score=0.758 total time=   2.9s
# [CV 5/5] END lda__n_components=10, lr__C=0.1, lr__solver=lbfgs, pca__n_components=256;, score=0.780 total time=   2.8s
# [CV 2/5] END lda__n_components=10, lr__C=0.1, lr__solver=lbfgs, pca__n_components=512;, score=0.644 total time=   6.7s
# [CV 3/5] END lda__n_components=10, lr__C=0.1, lr__solver=lbfgs, pca__n_components=512;, score=0.703 total time=   7.6s
# [CV 1/5] END lda__n_components=10, lr__C=0.1, lr__solver=lbfgs, pca__n_components=512;, score=0.658 total time=   7.3s
# [CV 4/5] END lda__n_components=10, lr__C=0.1, lr__solver=lbfgs, pca__n_components=512;, score=0.708 total time=   6.3s
# [CV 5/5] END lda__n_components=10, lr__C=0.1, lr__solver=lbfgs, pca__n_components=512;, score=0
5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=256;, score=0.731 total time=   6.2s
# [CV 4/5] END lda__n_components=None, lr__C=1, lr__solver=lbfgs, pca__n_components=784;, score=0.740 total time=   7.8s
# [CV 4/5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=256;, score=0.817 total time=   4.1s
# [CV 5/5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=256;, score=0.803 total time=   5.3s
# [CV 2/5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=512;, score=0.740 total time=   7.5s
# [CV 1/5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=512;, score=0.767 total time=   8.7s
# [CV 3/5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=512;, score=0.758 total time=   8.3s
# [CV 4/5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=512;, score=0.826 total time=   8.4s
# [CV 5/5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=512;, score=0.817 total time=   9.2s
# [CV 1/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=256;, score=0.767 total time=   2.4s
# [CV 2/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=256;, score=0.712 total time=   2.5s
# [CV 3/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=256;, score=0.772 total time=   2.2s
# [CV 4/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=256;, score=0.808 total time=   2.2s
# [CV 5/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=256;, score=0.775 total time=   2.0s
# [CV 2/5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=784;, score=0.712 total time=  12.2s
# [CV 1/5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=784;, score=0.744 total time=  13.3s
# [CV 3/5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=784;, score=0.763 total time=  12.9s
# [CV 2/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=512;, score=0.753 total time=   4.8s
# [CV 1/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=512;, score=0.753 total time=   5.2s
# [CV 5/5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=784;, score=0.780 total time=  10.8s
# [CV 3/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=512;, score=0.744 total time=   5.3s
# [CV 4/5] END lda__n_components=None, lr__C=1, lr__solver=sag, pca__n_components=784;, score=0.749 total time=  13.0s
# [CV 4/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=512;, score=0.817 total time=   7.8s
# [CV 5/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=512;, score=0.807 total time=   7.4s
# [CV 1/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=784;, score=0.740 total time=   6.8s
# [CV 2/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=784;, score=0.717 total time=   6.3s
# [CV 3/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=784;, score=0.753 total time=   7.2s
# [CV 1/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=256;, score=0.740 total time=   5.1s
# [CV 5/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=784;, score=0.771 total time=   6.2s
# [CV 4/5] END lda__n_components=None, lr__C=10, lr__solver=lbfgs, pca__n_components=784;, score=0.735 total time=   7.4s
# [CV 4/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=256;, score=0.808 total time=   4.4s
# [CV 2/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=256;, score=0.703 total time=   6.8s
# [CV 3/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=256;, score=0.767 total time=   6.7s
# [CV 5/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=256;, score=0.775 total time=   5.4s
# [CV 2/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=512;, score=0.731 total time=   8.5s
# [CV 4/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=512;, score=0.813 total time=   8.5s
# [CV 3/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=512;, score=0.763 total time=  10.3s
# [CV 5/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=512;, score=0.835 total time=   9.6s
# [CV 2/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=784;, score=0.721 total time=   7.8s
# [CV 1/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=512;, score=0.767 total time=  12.0s
# [CV 1/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=784;, score=0.740 total time=   8.4s
# [CV 3/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=784;, score=0.758 total time=   8.5s
# [CV 4/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=784;, score=0.740 total time=   5.1s
# [CV 5/5] END lda__n_components=None, lr__C=10, lr__solver=sag, pca__n_components=784;, score=0.771 total time=   5.5s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('pca', PCA()),
#                                        ('lda', LinearDiscriminantAnalysis()),
#                                        ('lr',
#                                         LogisticRegression(max_iter=10000))]),
#              n_jobs=-1,
#              param_grid={'lda__n_components': [10, 15, None],
#                          'lr__C': [0.1, 1, 10], 'lr__solver': ['lbfgs', 'sag'],
#                          'pca__n_components': [256, 512, 784]},
#              verbose=3)

# %% [markdown]
# ### **Best Hyperparameter Values**
#
# After multiple trials, over $500+$ individual fits were performed to find the optimal hyperparameter values for the pipeline. The best hyperparameter values are shown below.

# %%
grid.best_params_
# Out:
# {'lda__n_components': None,
#  'lr__C': 0.1,
#  'lr__solver': 'sag',
#  'pca__n_components': 256}

# %% [markdown]
# ### **Grid Search Results**
#
# The grid search was thoroughly evaluated before the final submission. The following cell shows the score of the "best" selected tuning of the grid on the validation set.

# %%
grid.score(x_test, y_test)
# Out:
# 0.8114754098360656

# %% [markdown]
# ## **Visualizing Feature Space**
#
# Having the optimal values for hyperparameters, the explained variance ratio of the `PCA` components, and the separation of the `LDA` components can be used to visualize the feature space.

# %% [markdown]
# ### **Explained Variance Trend**
#
# The following plot shows the explained variance trend of the `PCA` components. It is clear that the first $191$ principal components explain $95\%$ of the variance in the data. $256$ components explain $92.85\%$ of the variance in the data.

# %%
pca = PCA(n_components=None)
pca.fit(train_data.x)
exp_var = np.cumsum(pca.explained_variance_ratio_)

plt.figure(figsize=(14, 5))

plt.axhline(y=0, color="black", linewidth=1.5)
plt.axvline(x=0, color="black", linewidth=1.5)
plt.plot(range(1, min(train_data.x.shape)+1), exp_var)
plt.plot([256, 256], [0, exp_var[255]], color="black", linestyle="--")
plt.plot([256], [exp_var[255]], marker="o", color="red", label="256 Components")

plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")

plt.title("Explained Variance by Number of Principal Components")
plt.grid(True)
plt.legend()
plt.show()

# %%
for trial in [0.85, 0.90, 0.95]:
    print(trial*100, "% variance explained by:", np.argmax(exp_var > trial) + 1, "Principal Components")

print(256, "Principal Components explain", exp_var[255]*100, "% of the variance")
# Out:
# 85.0 % variance explained by: 119 Principal Components
# 90.0 % variance explained by: 191 Principal Components
# 95.0 % variance explained by: 329 Principal Components
# 256 Principal Components explain 92.85585481795418 % of the variance

# %% [markdown]
# ### **Inter-Class Separation after `LDA`**
#
# The following plot shows the separation of the `LDA` components. It shows the separation of each class after `LDA` is applied to the data. It is clear that the classes are well separated.

# %%
lda = LDA(n_components=None)
lda_data = lda.fit_transform(train_data.x, train_data.y)

labels = train_data.get_cat_to_label()
plt.figure(figsize=(6.5, 10.5))

for i, features in enumerate([range(6), range(6, 12), range(12, 18)], start=1):
    plt.subplot(3, 1, i)   
    for j in features:
        plt.hist(lda_data[train_data.y == j, j], label=labels[j], alpha=0.75, bins=25)
        plt.xlabel("LDA")
        plt.ylabel("Number of Samples")
        plt.grid(True)

plt.subplot(3, 1, 1)
plt.title("LDA Components")
plt.show()

# %% [markdown]
# ## **Training the Final Classifier**
#
# The final classifier is trained using the best hyperparameter values found above. The classifier is then used to predict the labels of the test set.

# %% [markdown]
# ## **Pipeline Training**
#
# The pipeline uses the finally decided algorithms as mentioned above with the hyperparameter values returned by the grid search. The pipeline is trained on the entire training set

# %%
pipe = Pipeline([
    ("pca", PCA(n_components=256)),
    ("lda", LDA()),
    ("lr", LogisticRegression(max_iter=10000, C=0.1, solver="sag"))
])

pipe.fit(train_data.x, train_data.y)
# Out:
# Pipeline(steps=[('pca', PCA(n_components=256)),
#                 ('lda', LinearDiscriminantAnalysis()),
#                 ('lr',
#                  LogisticRegression(C=0.1, max_iter=10000, solver='sag'))])

# %% [markdown]
# ## **Predictions on Test Set**
#
# Finally, the predictions are made on the test set using the trained pipeline. The predictions are saved in `submission.csv` file and uploaded to the Kaggle Challenge.

# %%
test_data = data.Dataset("test.csv")
test_data.x = scaler.transform(test_data.x)
pred = pipe.predict(test_data.x)
data.write_to_csv("submission.csv", pred, train_data.get_cat_to_label())

# %% [markdown]
# ## **Conclusion and Results**
#
# This attempt achieved a score of $0.82692$ on the entire test set, leading to a rank of $5$ out of $57$ teams on the leaderboard.
